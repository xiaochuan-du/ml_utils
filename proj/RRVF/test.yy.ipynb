# %%
import pandas as pd
import keras
import utils
from keras.models import model_from_yaml
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 10, 20
import numpy as np
from pandas_summary import DataFrameSummary
from importlib import reload
reload(utils)

# %matplotlib inline

# %% [markdown]
# ## NN

# %%
# load data
data_dir = r'./data'
trn = pd.read_csv('{}/air_visit_data.csv'.format(data_dir))
data = {
    'tra': pd.read_csv('{}/air_visit_data.csv'.format(data_dir)),
    # 'tes': pd.read_csv('{}/sample_submission.csv'.format(data_dir)),
    'as': pd.read_csv('{}/air_store_info.csv'.format(data_dir)),
    'hs': pd.read_csv('{}/hpg_store_info.csv'.format(data_dir)),
    'ar': pd.read_csv('{}/air_reserve.csv'.format(data_dir)),
    'hr': pd.read_csv('{}/hpg_reserve.csv'.format(data_dir)),
    'id': pd.read_csv('{}/store_id_relation.csv'.format(data_dir)),
    'hol': pd.read_csv('{}/date_info.csv'.format(data_dir))
}
# Prepare store info
data['as'] = data['as'].rename({'latitude': 'air_latitude', 'longitude': 'air_longitude'}, axis='columns')
data['hs'] = data['hs'].rename({'latitude': 'hpg_latitude', 'longitude': 'hpg_longitude'}, axis='columns')
stores = pd.merge(data['as'],  data['id'], how='left' )
stores = pd.merge(stores,  data['hs'], how='left')
# only use air_store_id
stores = stores.drop(columns=['hpg_store_id'])

# Prepare static of stores
key = 'air_store_id'
agg = data['tra'].groupby(key).agg([np.min, np.max, np.mean, np.std]).rename(
  columns={
    'amin': 'min_{}'.format('visits'),
    'amax': 'max_{}'.format('visits'),
    'mean': 'mean_{}'.format('visits'),
    'std': 'std_{}'.format('visits')
})
agg.reset_index(inplace=True)
agg.columns = agg.columns.droplevel()
agg = agg.reset_index()
agg.rename(
    {
        '': key,
}, axis='columns', inplace=True)

#merge store statics into store info
stores = pd.merge(stores, agg)

# %%
stores.to_csv('./insight/store_stas.csv')

# %%
with open('result/model_bn.yml') as file_obj:
    model_yml = file_obj.read()

# %%
model = model_from_yaml(model_yml)

# %%
model.load_weights('result/model_bn_yy.h5')

# %%
data_dir = r'./data'
trn = pd.read_csv('{}/air_visit_data.csv'.format(data_dir))
feas = utils.data2fea(trn, data_dir)
input_map = feas['x_map']
y = feas['y']
contin_cols = feas['contin_cols']
cat_map_fit = feas['cat_map_fit']
ts_date = feas['times']
s_i = ts_date[ts_date == '2016-04-23'].index[0]
e_i = ts_date[ts_date == '2016-06-01'].index[0]
# valid & trn splitting
map_train, map_valid, y_train_orig, y_valid_orig = utils.ts_data_split(input_map, y, s_i, e_i)
y_train, y_valid, max_log_y = utils.uniform_y(y_train_orig, y_valid_orig)
# Out:
# /home/ec2-user/ai/ml_utils/proj/RRVF/utils.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   store_info.drop_duplicates(inplace=True)
# /usr/local/lib64/python3.6/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /home/ec2-user/ai/ml_utils/proj/RRVF/utils.py:387: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hpg_store_info.drop('src', axis=1, inplace=True, errors="ignore")
# /usr/local/lib64/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
pred_valid = model.predict(map_valid)
# pred_valid_orig = utils.log_max_inv(pred_valid, max_log_y/2)*2

# %%
plt.figure(figsize=(20, 10))
plt.plot(y_valid.values)
plt.plot(pred_valid.flatten())

# %%
pred_trn = model.predict(map_train)
pred_trn_orig = utils.log_max_inv(pred_trn, max_log_y)

# %%
# edge s_p = 13100
s_p = 15200
win_len = 100

plt.figure(figsize=(20, 10))
plt.plot(y_train_orig[s_p:s_p+win_len])
plt.plot(pred_trn_orig[s_p:s_p+win_len].flatten())

# %%
map_train[11]
# Out:
# array([[-0.78972417, -0.79253807, -0.27968274, ..., -0.23305971,
#          0.16854959,  0.07280731],
#        [-0.78972417, -0.79253807, -0.27968274, ..., -0.23305971,
#          0.16854959,  0.07280731],
#        [-0.78972417, -0.79253807, -0.27968274, ..., -0.23305971,
#          0.16854959,  0.07280731],
#        ...,
#        [-0.78972417, -0.79253807, -0.27968274, ..., -0.74194521,
#         -1.43548391, -1.44901045],
#        [-0.78972417, -0.79253807, -0.27968274, ..., -0.74194521,
#         -1.43548391, -1.44901045],
#        [-0.78972417, -0.79253807, -0.27968274, ..., -0.74194521,
#         -1.43548391, -1.44901045]])

# %%
# edge s_p = 13100
s_p = 15200
win_len = 100

plt.figure(figsize=(20, 10))
plt.plot(y_train_orig[s_p:s_p+win_len])
plt.plot(pred_trn_orig[s_p:s_p+win_len].flatten())

# %%
plt.hist(y_train_orig)
# Out:
# (array([  2.51098000e+05,   9.31000000e+02,   3.30000000e+01,
#           9.00000000e+00,   3.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   2.00000000e+00,   1.00000000e+00,
#           1.00000000e+00]),
#  array([   1. ,   88.6,  176.2,  263.8,  351.4,  439. ,  526.6,  614.2,
#          701.8,  789.4,  877. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(y_train)
# Out:
# (array([  4.81100000e+03,   1.36420000e+04,   3.29410000e+04,
#           6.41440000e+04,   7.52910000e+04,   5.37180000e+04,
#           7.26700000e+03,   2.38000000e+02,   2.20000000e+01,
#           5.00000000e+00]),
#  array([ 0.  ,  0.08,  0.16,  0.24,  0.32,  0.4 ,  0.48,  0.56,  0.64,
#          0.72,  0.8 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(pred_trn)
# Out:
# (array([  1.73200000e+03,   1.83500000e+03,   4.14500000e+03,
#           1.25570000e+04,   1.43593000e+05,   6.70450000e+04,
#           1.77280000e+04,   3.21000000e+03,   2.08000000e+02,
#           2.60000000e+01]),
#  array([  7.62157072e-07,   6.63138991e-02,   1.32627036e-01,
#           1.98940173e-01,   2.65253310e-01,   3.31566447e-01,
#           3.97879584e-01,   4.64192720e-01,   5.30505857e-01,
#           5.96818994e-01,   6.63132131e-01]),
#  <a list of 10 Patch objects>)

# %%
data_dir = r'./data'
trn = pd.read_csv('{}/air_visit_data.csv'.format(data_dir))
feas = utils.data2fea(trn, data_dir)

# %%
trn_like_test.head()
# Out:
#            air_store_id  visit_date  visitors
# 0  air_00a91d42b08b08d9  2017-04-23       100
# 1  air_00a91d42b08b08d9  2017-04-24       100
# 2  air_00a91d42b08b08d9  2017-04-25       100
# 3  air_00a91d42b08b08d9  2017-04-26       100
# 4  air_00a91d42b08b08d9  2017-04-27       100

# %%
# Out:
# array([ 70.,  16.,  30., ...,  21.,  65.,  74.])

# %% [markdown]
# # Submission

# %%
data_dir = r'./data'
test = pd.read_csv('{}/sample_submission.csv'.format(data_dir))
trn_like_test = utils.tes2trn(test)
trn_like_test = trn_like_test.assign(visitors = np.round(np.random.rand(len(trn_like_test)) * 100))
feas = utils.data2fea(trn_like_test, data_dir)
input_map = feas['sk_fea']
y = feas['y']

# %%
pred_test = model.predict(input_map)
pred_test_orig = utils.log_max_inv(pred_test, max_log_y)
# pred_test_orig[pred_test_orig>1000] = pred_test_orig[pred_test_orig<1000].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-8a1c8e778b5b> in <module>()
# ----> 1 pred_test = model.predict(input_map)
#       2 pred_test_orig = utils.log_max_inv(pred_test, max_log_y)
#       3 # pred_test_orig[pred_test_orig>1000] = pred_test_orig[pred_test_orig<1000].mean()
#
# /usr/local/lib64/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1770         x = _standardize_input_data(x, self._feed_input_names,
#    1771                                     self._feed_input_shapes,
# -> 1772                                     check_batch_axis=False)
#    1773         if self.stateful:
#    1774             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# /usr/local/lib64/python3.6/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#      86                                  'the following list of ' + str(len(data)) +
#      87                                  ' arrays: ' + str(data)[:200] +
# ---> 88                                  '...')
#      89             else:
#      90                 if len(names) == 1:
#
# ValueError: Error when checking model : the list of Numpy arrays that you are passing to your model is not the size the model expected. Expected to see 13 array(s), but instead got the following list of 12 arrays: [array([[ 6],
#        [ 6],
#        [ 6],
#        ...,
#        [12],
#        [12],
#        [12]]), array([[32],
#        [32],
#        [32],
#        ...,
#        [64],
#        [64],
#        [64]]), array([[15],
# ...

# %%
plt.plot(pred_test_orig)

# %%
test.visitors = pred_test_orig

# %%
test.to_csv('result/submission.csv', index=False)

# %% [markdown]
# # Explore results

# %%
data_dir = r'./data'
trn = pd.read_csv('{}/air_visit_data.csv'.format(data_dir))
feas = utils.data2fea(trn, data_dir)
input_map = feas['x_map']
y = feas['y']
# Out:
# /home/ec2-user/ai/ml_utils/proj/RRVF/utils.py:358: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   store_info.drop_duplicates(inplace=True)
# /usr/local/lib64/python3.6/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /home/ec2-user/ai/ml_utils/proj/RRVF/utils.py:369: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hpg_store_info.drop('src', axis=1, inplace=True, errors="ignore")

# %%
pred_trn = model.predict(input_map)
pred_trn_orig = utils.log_max_inv(pred_trn, max_log_y)
trn = trn.assign(pred=pred_trn_orig)
trn = trn.assign(diff_val=np.abs(trn.pred - trn.visitors))
trn = trn.assign(diff_ratio=np.divide(trn.diff_val, trn.visitors))

# %%
DataFrameSummary(trn).summary()
# Out:
#              air_store_id visit_date visitors visit_date_week  \
# count                 NaN        NaN   252108          252108
# mean                  NaN        NaN  20.9738          25.001
# std                   NaN        NaN   16.757         16.0084
# min                   NaN        NaN        1               1
# 25%                   NaN        NaN        9              10
# 50%                   NaN        NaN       17              26
# 75%                   NaN        NaN       29              39
# max                   NaN        NaN      877              53
# counts             252108     252108   252108          252108
# uniques               829        478      204              53
# missing                 0          0        0               0
# missing_perc           0%         0%       0%              0%
# types         categorical       date  numeric         numeric
#
#              visit_date_dayofweek visit_date_year visit_date_month     pred  \
# count                      252108          252108           252108   252108
# mean                      3.01968         2016.31           6.2082  19.4187
# std                       1.92399        0.461542          3.68026  13.8287
# min                             0            2016                1        1
# 25%                             1            2016                3  9.00508
# 50%                             3            2016                7  16.0588
# 75%                             5            2017               10  26.3859
# max                             6            2017               12  206.999
# counts                     252108          252108           252108   252108
# uniques                         7               2               12   248368
# missing                         0               0                0        0
# missing_perc                   0%              0%               0%       0%
# types                     numeric            bool          numeric  numeric
#
#                  diff diff_val diff_ratio
# count          252108   252108     252108
# mean          5.84301  5.84301   0.424395
# std           7.65068  7.65068   0.769973
# min                 0        0          0
# 25%           1.69926  1.69926   0.118536
# 50%           3.86901  3.86901   0.252894
# 75%           7.63295  7.63295   0.449575
# max           859.973  859.973    32.3515
# counts         252108   252108     252108
# uniques        249496   249496     251244
# missing             0        0          0
# missing_perc       0%       0%         0%
# types         numeric  numeric    numeric

# %%
agg = trn.groupby('air_store_id').mean()

# %%
agg = agg.sort_values('diff_ratio')

# %%
DataFrameSummary(agg).summary()
# Out:
#              visitors visit_date_week visit_date_dayofweek visit_date_year  \
# count             829             829                  829             829
# mean          21.2039           25.43              3.02443         2016.33
# std            11.775         3.32288             0.302565        0.120549
# min            1.1875         10.3667              2.03191            2016
# 25%            11.812         22.4159              2.91039         2016.24
# 50%           19.1834         27.4475              3.02114         2016.37
# 75%           28.6452         27.7973              3.16239         2016.38
# max           115.471         36.1753                4.775            2017
# counts            829             829                  829             829
# uniques           828             803                  760             634
# missing             0               0                    0               0
# missing_perc       0%              0%                   0%              0%
# types         numeric         numeric              numeric         numeric
#
#              visit_date_month     pred      diff  diff_val diff_ratio
# count                     829      829       829       829        829
# mean                  6.30872  19.6738   5.85496   5.85496   0.423868
# std                  0.765667  11.6707   2.78625   2.78625   0.156497
# min                   2.83333  1.00132  0.188525  0.188525  0.0723492
# 25%                   5.60403  10.6193   3.90871   3.90871   0.311818
# 50%                   6.77083   17.315    5.4273    5.4273   0.411022
# 75%                   6.85659  26.9636    7.2956    7.2956   0.516158
# max                   8.78351  112.424   26.8287   26.8287    1.59998
# counts                    829      829       829       829        829
# uniques                   777      829       829       829        829
# missing                     0        0         0         0          0
# missing_perc               0%       0%        0%        0%         0%
# types                 numeric  numeric   numeric   numeric    numeric

# %%
agg[ (agg.diff_ratio < 0.8) & (agg.diff_ratio > 0.6)].head()
# Out:
#                        visitors  visit_date_week  visit_date_dayofweek  \
# air_store_id
# air_bcce1ea4350b7b72  16.598592        27.665493              3.042254
# air_0164b9927d20bcc3   9.248322        25.335570              2.557047
# air_aed3a8b49abe4a48   9.080000        27.854545              3.061818
# air_ee3ba9af184c6c82  13.348684        31.750000              2.940789
# air_457efe8c3a30ea17   6.909326        22.238342              2.748705
#
#                       visit_date_year  visit_date_month       pred      diff  \
# air_store_id
# air_bcce1ea4350b7b72      2016.369718          6.841549  13.892851  6.700159
# air_0164b9927d20bcc3      2016.557047          6.268456   7.322750  4.034711
# air_aed3a8b49abe4a48      2016.360000          6.880000   7.566768  3.612044
# air_ee3ba9af184c6c82      2016.250000          7.776316  10.843468  5.682018
# air_457efe8c3a30ea17      2016.230570          5.577720   5.766316  3.036346
#
#                       diff_val  diff_ratio
# air_store_id
# air_bcce1ea4350b7b72  6.700159    0.601095
# air_0164b9927d20bcc3  4.034711    0.601766
# air_aed3a8b49abe4a48  3.612044    0.602255
# air_ee3ba9af184c6c82  5.682018    0.602320
# air_457efe8c3a30ea17  3.036346    0.602718

# %%
plt.figure(figsize=(20, 10))
a_store = trn[trn.air_store_id == "air_457efe8c3a30ea17"]
a_store.visit_date = pd.to_datetime(a_store.visit_date)
a_store = a_store.set_index('visit_date')
a_store['2016-04'].visitors.plot()
a_store['2016-04'].pred.plot()
# Out:
# /usr/local/lib64/python3.6/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# # Worst cases
#
# ## 点少
# - air_52a08ef3efdb4bb0
#
# ## 变化幅度大
# - air_8e492076a1179383 变化幅度大 20 ~ 100
# - air_4c2ed28f3f19ca52 变化幅度大
# - air_df507aec929ce5f6
# - air_9387ff95e886ebc7
#
# 20~50
#  - air_22682e965418936f
#  - air_3155ee23d92202da
#
# Period change
#  - air_93dd7070c9bf5453
#
# 非常奇怪：
# air_9828505fefc77d75
#  ## 好的
#  30 ~ 60 change
#  20 ~ 40

# %% [markdown]
# # Xgboost

# %%
import glob
import re
import pickle

import numpy as np
import pandas as pd
from isoweek import Week
from pandas_summary import DataFrameSummary
from keras.models import model_from_yaml
import utils
from keras.callbacks import TensorBoard, ModelCheckpoint
import xgboost
import random
import matplotlib.pyplot as plt, xgboost, operator, random, pickle
reload(utils)

import math
def rmsle(y_pred, targ):
#     display(y_pred.shape, targ.shape)
    log_vars = np.log(targ + 1) - np.log(y_pred + 1)
    return math.sqrt(np.square(log_vars).mean())

# %%
data_dir = r'./data'
trn = pd.read_csv('{}/air_visit_data.csv'.format(data_dir))

drop_vars = [
 'af_holiday_flg', 
 'be_holiday_flg',
 'min_visits_in_hpb_loc',
 'min_visits_in_area_name',
#  'holiday_flg',
 'stores_in_hpb_loc',
#  'dur_time_holiday_flg',
 'std_visits_in_hpb_loc',
 'mean_visits_in_hpb_loc',
 'stores_in_hpb_area_name',
 'min_visits_in_hpb_area_name',
 'min_visits_in_air_loc',
#  'dur_prog_holiday_flg',
 'max_visits_in_hpb_area_name',
 'max_visits_in_hpb_loc',
 'std_visits_in_hpb_area_name',
 'mean_visits_in_hpb_area_name',
 'std_visits_in_area_name',
 'visit_date_year',
 'stores_in_air_loc',
 'max_visits_in_air_loc',
#  'dur_holiday_flg',
 'hpb_area_name',
 'mean_visits_in_area_name'
]
# drop_vars = []

feas = utils.data2fea(trn, data_dir, drop_vars=drop_vars)
# trn = trn[trn.air_store_id.isin(trn.air_store_id.unique()[:1])]
# trn = trn[trn.air_store_id.isin(['air_17a6ab40f97fd4d8'])]

# %%
input_map = feas['sk_fea']

y = feas['y']
contin_cols = feas['contin_cols']
cat_map_fit = feas['cat_map_fit']
tidy_data = feas['tidy_data']
all_vars = feas['all_vars']
# ts_date = feas['times']
date_sr = pd.to_datetime(tidy_data.Date)
dat = utils.data_split_by_date(
    input_map, y, date_sr, trn2val_ratio=8, step_days=150)
# # valid & trn splitting
dat_d = dat[0]
X_train, y_train_orig, X_valid, y_valid_orig = dat_d['x_trn'], dat_d['y_trn'], dat_d['x_valid'], dat_d['y_valid']
y_train, y_valid, max_log_y = utils.uniform_y(y_train_orig, y_valid_orig)
# max_log_y = feas['max_log_y']

xdata = xgboost.DMatrix(X_train, y_train, feature_names=all_vars)
xdata_val = xgboost.DMatrix(X_valid, y_valid, feature_names=all_vars)

# %%
print(dat_d['x_trn'].shape, dat_d['x_valid'].shape, dat_d['y_trn'].shape, dat_d['y_valid'].shape)
# Out:
# (31145, 21) (7787, 21) (31145,) (7787,)

# %%
all_vars = feas['all_vars']
def rmsle_wo_log(y_predicted, y_true):
    y_true = y_true.get_label()
    y_predicted_orig = utils.log_max_inv(y_predicted, max_log_y)
    y_true_orig = utils.log_max_inv(y_true, max_log_y)
    score = rmsle(y_predicted_orig, y_true_orig)
    return ('rmsle', score)

evallist = [(xdata_val, 'eval'), (xdata, 'train')]
eval_grid = []
depths = np.array(range(10, 100, 5))
for dept in [25]:
    evals_result = {}
    xgb_parms = {
       'learning_rate': 0.1,
       'subsample': 0.8,
       'colsample_bylevel': 0.8,
       'silent': False,
       'objective': 'reg:linear',
       'seed': random.randint(0,1e9),
       "nthread": 4,
       'max_depth': dept #  4,6,8,10,15
    }
    model = xgboost.train(xgb_parms,
                         xdata,
                         num_boost_round=40,
                         evals=evallist,
                         feval=rmsle_wo_log,
                         evals_result=evals_result,# result will be saved here
                         xgb_model=None,  # load previous model            
                         verbose_eval = 5,
                         early_stopping_rounds = 10)
    model.eval(xdata_val)
    pred_valid = model.predict(xdata_val)
    pred_valid_orig = utils.log_max_inv(pred_valid, max_log_y)
#     y_valid_orig = utils.log_max_inv(y_valid, max_log_y)
    valid_loss = rmsle(pred_valid_orig, y_valid_orig)
    pred_trn = model.predict(xdata)
    pred_trn_orig = utils.log_max_inv(pred_trn, max_log_y)
#     y_train_orig = utils.log_max_inv(y_train, max_log_y)
    trn_loss = rmsle(pred_trn_orig, y_train_orig)
    eval_grid.append(evals_result)
    print('train loss: {}, valid loss: {}'.format(trn_loss, valid_loss))
# Out:
# [0]	eval-rmse:0.157605	train-rmse:0.154893	eval-rmsle:1.23014	train-rmsle:1.20897
# Multiple eval metrics have been passed: 'train-rmsle' will be used for early stopping.
#
# Will train until train-rmsle hasn't improved in 10 rounds.
# [5]	eval-rmse:0.120508	train-rmse:0.106107	eval-rmsle:0.940588	train-rmsle:0.828189
# [10]	eval-rmse:0.104637	train-rmse:0.076286	eval-rmsle:0.81671	train-rmsle:0.595428
# [15]	eval-rmse:0.098567	train-rmse:0.057327	eval-rmsle:0.769335	train-rmsle:0.447451
# [20]	eval-rmse:0.096446	train-rmse:0.045414	eval-rmsle:0.75278	train-rmsle:0.354462
# [25]	eval-rmse:0.096044	train-rmse:0.037218	eval-rmsle:0.749646	train-rmsle:0.290494
# [30]	eval-rmse:0.096186	train-rmse:0.031208	eval-rmsle:0.750748	train-rmsle:0.243586
# [35]	eval-rmse:0.096487	train-rmse:0.026783	eval-rmsle:0.753105	train-rmsle:0.209047
# [39]	eval-rmse:0.09681	train-rmse:0.024051	eval-rmsle:0.755625	train-rmsle:0.187725
# train loss: 0.1877248884324816, valid loss: 0.7556250128289025

# %% [markdown]
# ## Tuning

# %%
## round = 0.2, max_depth = 12, compare rate
rates = np.array(range(1, 5, 1)) * 0.1
# for nrate in rates:
#     evals_result = {}
#     xgb_parms = {
#        'learning_rate': nrate,
#        'subsample': 0.95,
#        'colsample_bylevel': 0.6,
#        'silent': True,
#        'objective': 'reg:linear',
#        'seed': random.randint(0,1e9),
#        "nthread": 4,
#        'max_depth': 12 #  4,6,8,10,15
#     }
#     model = xgboost.train(xgb_parms,
#                          xdata,
#                          num_boost_round=60,
#                          evals=evallist,
#                          feval=rmsle_wo_log,
#                          evals_result=evals_result,# result will be saved here
#                          xgb_model=None,  # load previous model
#                          verbose_eval=False)
#     # model.eval(xdata_val)
#     pred_valid = model.predict(xdata_val)
#     pred_valid_orig = utils.log_max_inv(pred_valid, max_log_y)
#     valid_loss = rmsle(pred_valid_orig, y_valid_orig)
#     pred_trn = model.predict(xdata)
#     pred_trn_orig = utils.log_max_inv(pred_trn, max_log_y)
#     trn_loss = rmsle(pred_trn_orig, y_train_orig)
#     eval_grid.append(evals_result)
#     print('train loss: {}, valid loss: {}'.format(trn_loss, valid_loss))

plt.figure(figsize=(20, 15))

for i in range(4):
    plt.subplot(2,3,i+1)
    er = eval_grid[i]
    plt.plot(er['train']['rmsle'], 'r')
    plt.plot(er['eval']['rmsle'])
    plt.plot([0, 60], [0.8, 0.8], 'y--')
    plt.plot([0, 60], [0.6, 0.6], 'g--')
    plt.title('max_depth, 12, num_round: 60, learning: rate: ' + str(rates[i]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-236-415d514cf87b> in <module>()
#      35 for i in range(4):
#      36     plt.subplot(2,3,i+1)
# ---> 37     er = eval_grid[i]
#      38     plt.plot(er['train']['rmsle'], 'r')
#      39     plt.plot(er['eval']['rmsle'])
#
# IndexError: list index out of range

# %%
## lr = 0.2, max_depth = 12, compare round
# rounds = range(40, 100, 10)
# for nround in rounds:
#     evals_result = {}
#     xgb_parms = {
#        'learning_rate': 0.2,
#        'subsample': 0.95,
#        'colsample_bylevel': 0.6,
#        'silent': True,
#        'objective': 'reg:linear',
#        'seed': random.randint(0,1e9),
#        "nthread": 4,
#        'max_depth': 12 #  4,6,8,10,15
#     }
#     model = xgboost.train(xgb_parms,
#                          xdata,
#                          num_boost_round=nround,
#                          evals=evallist,
#                          feval=rmsle_wo_log,
#                          evals_result=evals_result,# result will be saved here
#                          xgb_model=None,  # load previous model
#                          verbose_eval=False)
#     # model.eval(xdata_val)
#     pred_valid = model.predict(xdata_val)
#     pred_valid_orig = utils.log_max_inv(pred_valid, max_log_y)
#     valid_loss = rmsle(pred_valid_orig, y_valid_orig)
#     pred_trn = model.predict(xdata)
#     pred_trn_orig = utils.log_max_inv(pred_trn, max_log_y)
#     trn_loss = rmsle(pred_trn_orig, y_train_orig)
#     eval_grid.append(evals_result)
#     print('train loss: {}, valid loss: {}'.format(trn_loss, valid_loss))
    
plt.figure(figsize=(20, 15))

for i in range(6):
    plt.subplot(2,3,i+1)
    er = eval_grid[i]
    plt.plot(er['train']['rmsle'], 'r')
    plt.plot(er['eval']['rmsle'])
    plt.plot([0, rounds[i]], [0.8, 0.8], 'y--')
    plt.plot([0, rounds[i]], [0.6, 0.6], 'g--')
    plt.title('max_depth, 12, learning: rate: 0.2, num_round: ' + str(rounds[i]))

# %%
## lr = 0.2, round = 40, compare max_depth
# depths = [4,6,8,10,12,15]
# for depth in depths:
#     evals_result = {}
#     xgb_parms = {
#        'learning_rate': 0.2,
#        'subsample': 0.95,
#        'colsample_bylevel': 0.6,
#        'silent': True,
#        'objective': 'reg:linear',
#        'seed': random.randint(0,1e9),
#        "nthread": 4,
#        'max_depth': depth #  4,6,8,10,15
#     }
#     model = xgboost.train(xgb_parms,
#                          xdata,
#                          num_boost_round=40,
#                          evals=evallist,
#                          feval=rmsle_wo_log,
#                          evals_result=evals_result,# result will be saved here
#                          xgb_model=None,  # load previous model
#                          verbose_eval=False)
#     # model.eval(xdata_val)
#     pred_valid = model.predict(xdata_val)
#     pred_valid_orig = utils.log_max_inv(pred_valid, max_log_y)
#     valid_loss = rmsle(pred_valid_orig, y_valid_orig)
#     pred_trn = model.predict(xdata)
#     pred_trn_orig = utils.log_max_inv(pred_trn, max_log_y)
#     trn_loss = rmsle(pred_trn_orig, y_train_orig)
#     eval_grid.append(evals_result)
#     print('train loss: {}, valid loss: {}'.format(trn_loss, valid_loss))
    
plt.figure(figsize=(20, 15))

for i in range(10):
    plt.subplot(2,5,i+1)
    er = eval_grid[i]
    plt.plot(er['train']['rmsle'], 'r')
    plt.plot(er['eval']['rmsle'])
    plt.plot([0, 40], [0.8, 0.8], 'y--')
    plt.plot([0, 40], [0.15, 0.15], 'y--')
    plt.title(' max_depth: ' + str(depths[i]))

# %%
plt.plot(evals_result['train']['rmsle'], 'r')
plt.plot(evals_result['eval']['rmsle'])

# %%
model.save_model('result/xgboost.h5')

# %% [markdown]
# ## Valid

# %%
pred_test = model.predict(xdata_val)
# pred_test_orig = utils.log_max_inv(pred_test, max_log_y)

# %%
pred_test
# Out:
# array([ 0.38666433,  0.30469021,  0.31861988, ...,  0.41603836,
#         0.46912032,  0.34894997], dtype=float32)

# %%
xgboost.plot_importance(model, max_num_features = 15)

# %%
importance = model.get_fscore()
importance = sorted(importance.items(), key=operator.itemgetter(1))
df = pd.DataFrame(importance, columns=['feature', 'fscore'])
df['fscore'] = df['fscore'] / df['fscore'].sum()
df.plot(kind='barh', x='feature', y='fscore', legend=False, figsize=(6, 10))
plt.title('XGBoost Feature Importance')
plt.xlabel('relative importance')
# Out:
# Text(0.5,0,'relative importance')

# %%
## Plot Valid Result
plt.figure(figsize=(20, 10))
plt.plot(y_valid_orig.values[1000:1100], 'r')
plt.plot(pred_valid_orig.flatten()[1000:1100])

# %%
## Plot Train Result
pred_trn = model.predict(xdata)
# pred_trn_orig = utils.log_max_inv(pred_trn, max_log_y)
plt.figure(figsize=(20, 10))
plt.plot(y_train_orig.values[24000:], 'r')
plt.plot(pred_trn_orig.flatten()[24000:])

# %% [markdown]
# ## Submit

# %%
data_dir = r'./data'
test = pd.read_csv('{}/sample_submission.csv'.format(data_dir))
trn_like_test = utils.tes2trn(test)
trn_like_test = trn_like_test.assign(visitors = np.round(np.random.rand(len(trn_like_test)) * 100))
# feas = utils.data2fea(trn_like_test, data_dir)
feas = utils.data2fea(trn_like_test, data_dir, drop_vars=drop_vars)
input_map = feas['sk_fea']
all_vars = feas['all_vars']
y = feas['y']
# Out:
#            air_store_id  visit_date  visitors
# 0  air_ba937bf13d40fb24  2016-01-13  0.384570
# 1  air_ba937bf13d40fb24  2016-01-14  0.412711
# 2  air_ba937bf13d40fb24  2016-01-15  0.401461
# 3  air_ba937bf13d40fb24  2016-01-16  0.370098
# 4  air_ba937bf13d40fb24  2016-01-18  0.229686

# %%
len(all_vars)
# input_map.shape
# Out:
# 21

# %%
input_map.shape
# Out:
# (32019, 21)

# %%
test_data = xgboost.DMatrix(input_map, feature_names=all_vars)

# %%
preded_test = model.predict(test_data)
pred_test_orig = utils.log_max_inv(preded_test, max_log_y)

# %%
test.visitors = pred_test_orig

# %%
test.to_csv('result/xgb.csv', index=False)
